# %% [markdown]
# # EDA before
#
# 3. [심화1] 아래 링크의 대용량 데이터에서 "서울"지역만 추려낸 뒤에, EDA 해보기
#
# 4. [심화2] 3번에서처럼 서울만 추려낸 뒤에, 위치정보(위경도) 피쳐 추가하기
#
#
#
# <목적>
#
# 3번은 대용량데이터를 경험해보기에 적절할 것 같습니다. 더불어 자연어처리 경험을 처음 접하기에 한국 데이터라서 편리합니다.
#
# 4번은 3번에 추가해서 크롤링을 연습하기에 좋은 자료입니다.
#
#
# (만약 2-4번 과제를 하신다면 - 직접 코딩하신 결과를 ipynb파일이나 html, pdf등으로 만들어주시면 되겠습니다~)

# %%
import pandas as pd
import numpy as np
import folium

# %% [markdown]
# ## import large data and find 서울

# %%
df = pd.read_csv('건물대장.txt', nrows=1, delimiter='\|',  engine='python', header=None)

# %%
df.drop(0, inplace=True)

# %%
for chunk in pd.read_csv('건물대장.txt', chunksize=1000, delimiter='\|',  engine='python', header=None):
    a = chunk[(chunk.iloc[:,7]+chunk.iloc[:,8]).apply(lambda x : x.find('서울')!=-1)]
    df = pd.concat([df,a])

# %%
df
# Out:
#                      0   1   2   3      4    5    6                       7   \
# 85            11500-493   1  일반   1  총괄표제부  1.0  신대장  서울특별시 강서구 등촌동 650-14번지
# 222           11740-450   2  집합   1  총괄표제부  1.0  신대장  서울특별시 강동구 암사동 422-26번지
# 223           11740-554   2  집합   1  총괄표제부  1.0  신대장    서울특별시 강동구 길동 352-3번지
# 318           11740-132   1  일반   1  총괄표제부  1.0  신대장     서울특별시 강동구 고덕동 580번지
# 759           11590-711   1  일반   1  총괄표제부  0.0  구대장   서울특별시 동작구 대방동 44-14번지
# ...                 ...  ..  ..  ..    ...  ...  ...                     ...
# 584445        11350-717   2  집합   1  총괄표제부  0.0  구대장     서울특별시 노원구 공릉동 743번지
# 584462        11215-624   1  일반   1  총괄표제부  0.0  구대장    서울특별시 광진구 자양동 6-15번지
# 584464        11530-164   2  집합   1  총괄표제부  0.0  구대장    서울특별시 구로구 신도림동 637번지
# 584480  11560-100192654   2  집합   1  총괄표제부  1.0  신대장   서울특별시 영등포구 당산동4가 96번지
# 584583        11560-780   2  집합   1  총괄표제부  0.0  구대장   서울특별시 영등포구 문래동4가 43번지
#
#                              8                           9   ...          54  \
# 85           서울특별시 강서구 공항대로 491                    서울백석초등학교  ...         NaN
# 222       서울특별시 강동구 구천면로 365-13                     암사e편한세상  ...  주택건설사업계획승인
# 223        서울특별시 강동구 천중로54길 9-9                       양촌아파트  ...        신축허가
# 318      서울특별시 강동구 아리수로61길 37-8                           1  ...    연서(신축허가)
# 759         서울특별시 동작구 등용로10다길 3                         NaN  ...         NaN
# ...                         ...                         ...  ...         ...
# 584445      서울특별시 노원구 공릉로46길 19                공릉동한보에센시티아파트  ...         NaN
# 584462                           자양동615제2종근린생활시설(광진자양새마을금고)  ...         NaN
# 584464     서울특별시 구로구 신도림로21길 25                    신도림우성아파트  ...         NaN
# 584480      서울특별시 영등포구 국회대로 597                 당산동반도유보라팰리스  ...  주택건설사업계획승인
# 584583    서울특별시 영등포구 도림로143길 32                    문래동삼환아파트  ...         NaN
#
#         55   56   57  58  59 60  61  62        63
# 85       0  NaN  0.0   0 NaN  0 NaN   0  20100628
# 222      0  NaN  0.0   0 NaN  0 NaN   0  20100417
# 223      0  NaN  0.0   0 NaN  0 NaN   0  20100417
# 318      0  NaN  0.0   0 NaN  0 NaN   0  20100417
# 759      0  NaN  0.0   0 NaN  0 NaN   0  20100417
# ...     ..  ...  ...  ..  .. ..  ..  ..       ...
# 584445  16  NaN  0.0   0 NaN  0 NaN   0  20190713
# 584462   0  NaN  0.0   0 NaN  0 NaN   0  20200221
# 584464   0  NaN  0.0   0 NaN  0 NaN   0  20200220
# 584480   0  NaN  0.0   0 NaN  0 NaN   0  20200224
# 584583   0  NaN  0.0   0 NaN  0 NaN   0  20190722
#
# [19989 rows x 64 columns]

# %%
df.columns = ['관리_건축물대장_PK',
              '대장_구분_코드',
              '대장_구분_코드_명',
              '대장_종류_코드',
              '대장_종류_코드_명',
              '신_구_대장_구분_코드',
              '신_구_대장_구분_코드_명',
              '대지_위치',
              '도로명_대지_위치',
              '건물_명',
              '시군구_코드',
              '법정동_코드',
              '대지_구분_코드',
              '번',
              '지',
              '특수지_명',
              '블록',
              '로트',
              '외필지_수',
              '새주소_도로_코드',
              '새주소_법정동_코드',
              '새주소_지상지하_코드',
              '새주소_본_번',
              '새주소_부_번',
              '대지_면적(㎡)',
              '건축_면적(㎡)',
              '건폐_율(%)',
              '연면적(㎡)',
              '용적_률_산정_연면적(㎡)',
              '용적_률(%)',
              '주_용도_코드',
              '주_용도_코드_명',
              '기타_용도',
              '세대_수(세대)',
              '가구_수(가구)',
              '주_건축물_수',
              '부속_건축물_수',
              '부속_건축물_면적(㎡)',
              '총_주차_수',
              '옥내_기계식_대수(대)',
              '옥내_기계식_면적(㎡)',
              '옥외_기계식_대수(대)',
              '옥외_기계식_면적(㎡)',
              '옥내_자주식_대수(대)',
              '옥내_자주식_면적(㎡)',
              '옥외_자주식_대수(대)',
              '옥외_자주식_면적(㎡)',
              '허가_일',
              '착공_일',
              '사용승인_일',
              '허가번호_년',
              '허가번호_기관_코드',
              '허가번호_기관_코드_명',
              '허가번호_구분_코드',
              '허가번호_구분_코드_명',
              '호_수(호)',
              '에너지효율_등급',
              '에너지절감_율',
              '에너지_EPI점수',
              '친환경_건축물_등급',
              '친환경_건축물_인증점수',
              '지능형_건축물_등급',
              '지능형_건축물_인증점수',
              '생성_일자']

# %%
df
# Out:
#             관리_건축물대장_PK  대장_구분_코드 대장_구분_코드_명  대장_종류_코드 대장_종류_코드_명  \
# 85            11500-493         1         일반         1      총괄표제부
# 222           11740-450         2         집합         1      총괄표제부
# 223           11740-554         2         집합         1      총괄표제부
# 318           11740-132         1         일반         1      총괄표제부
# 759           11590-711         1         일반         1      총괄표제부
# ...                 ...       ...        ...       ...        ...
# 584445        11350-717         2         집합         1      총괄표제부
# 584462        11215-624         1         일반         1      총괄표제부
# 584464        11530-164         2         집합         1      총괄표제부
# 584480  11560-100192654         2         집합         1      총괄표제부
# 584583        11560-780         2         집합         1      총괄표제부
#
#         신_구_대장_구분_코드 신_구_대장_구분_코드_명                   대지_위치  \
# 85               1.0            신대장  서울특별시 강서구 등촌동 650-14번지
# 222              1.0            신대장  서울특별시 강동구 암사동 422-26번지
# 223              1.0            신대장    서울특별시 강동구 길동 352-3번지
# 318              1.0            신대장     서울특별시 강동구 고덕동 580번지
# 759              0.0            구대장   서울특별시 동작구 대방동 44-14번지
# ...              ...            ...                     ...
# 584445           0.0            구대장     서울특별시 노원구 공릉동 743번지
# 584462           0.0            구대장    서울특별시 광진구 자양동 6-15번지
# 584464           0.0            구대장    서울특별시 구로구 신도림동 637번지
# 584480           1.0            신대장   서울특별시 영등포구 당산동4가 96번지
# 584583           0.0            구대장   서울특별시 영등포구 문래동4가 43번지
#
#                       도로명_대지_위치                        건물_명  ...  \
# 85           서울특별시 강서구 공항대로 491                    서울백석초등학교  ...
# 222       서울특별시 강동구 구천면로 365-13                     암사e편한세상  ...
# 223        서울특별시 강동구 천중로54길 9-9                       양촌아파트  ...
# 318      서울특별시 강동구 아리수로61길 37-8                           1  ...
# 759         서울특별시 동작구 등용로10다길 3                         NaN  ...
# ...                         ...                         ...  ...
# 584445      서울특별시 노원구 공릉로46길 19                공릉동한보에센시티아파트  ...
# 584462                           자양동615제2종근린생활시설(광진자양새마을금고)  ...
# 584464     서울특별시 구로구 신도림로21길 25                    신도림우성아파트  ...
# 584480      서울특별시 영등포구 국회대로 597                 당산동반도유보라팰리스  ...
# 584583    서울특별시 영등포구 도림로143길 32                    문래동삼환아파트  ...
#
#         허가번호_구분_코드_명  호_수(호)  에너지효율_등급  에너지절감_율  에너지_EPI점수 친환경_건축물_등급  \
# 85               NaN       0       NaN      0.0          0        NaN
# 222       주택건설사업계획승인       0       NaN      0.0          0        NaN
# 223             신축허가       0       NaN      0.0          0        NaN
# 318         연서(신축허가)       0       NaN      0.0          0        NaN
# 759              NaN       0       NaN      0.0          0        NaN
# ...              ...     ...       ...      ...        ...        ...
# 584445           NaN      16       NaN      0.0          0        NaN
# 584462           NaN       0       NaN      0.0          0        NaN
# 584464           NaN       0       NaN      0.0          0        NaN
# 584480    주택건설사업계획승인       0       NaN      0.0          0        NaN
# 584583           NaN       0       NaN      0.0          0        NaN
#
#        친환경_건축물_인증점수 지능형_건축물_등급  지능형_건축물_인증점수     생성_일자
# 85                0        NaN             0  20100628
# 222               0        NaN             0  20100417
# 223               0        NaN             0  20100417
# 318               0        NaN             0  20100417
# 759               0        NaN             0  20100417
# ...             ...        ...           ...       ...
# 584445            0        NaN             0  20190713
# 584462            0        NaN             0  20200221
# 584464            0        NaN             0  20200220
# 584480            0        NaN             0  20200224
# 584583            0        NaN             0  20190722
#
# [19989 rows x 64 columns]

# %%
df.to_csv('서울건물대장.txt')

# %%
# df = pd.read_csv('서울건물대장.txt')
